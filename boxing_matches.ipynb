# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import mlxtend
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from scipy.sparse import csr_matrix
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
 

df = pd.read_csv('popular_matches.csv')

# %% [markdown]
# DATA PREPROCESSING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   opponent_1                                  152 non-null    object
#  1   opponent_2                                  152 non-null    object
#  2   opponent_1_estimated_punch_power            152 non-null    int64
#  3   opponent_2_estimated_punch_power            152 non-null    int64
#  4   opponent_1_estimated_punch_resistance       150 non-null    float64
#  5   opponent_2_estimated_punch_resistance       144 non-null    float64
#  6   opponent_1_estimated_ability_to_take_punch  151 non-null    float64
#  7   opponent_2_estimated_ability_to_take_punch  145 non-null    float64
#  8   opponent_1_rounds_boxed                     152 non-null    int64
#  9   opponent_2_rounds_boxed                     125 non-null    float64
#  10  opponent_1_round_ko_percentage              128 non-null    float64
#  11  opponent_2_round_ko_percentage              134 non-null    float64
#  12  opponent_1_has_been_ko_percentage           135 non-null    float64
#  13  opponent_2_has_been_ko_percentage           97 non-null     float64
#  14  opponent_1_avg_weight                       151 non-null    float64
#  15  opponent_2_avg_weight                       140 non-null    float64
#  16  Result                                      152 non-null    object
# dtypes: float64(11), int64(3), object(3)
# memory usage: 20.3+ KB

# %%
#drop missing values
df_d = df.dropna()

# %%
df_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 151
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   opponent_1                                  60 non-null     object
#  1   opponent_2                                  60 non-null     object
#  2   opponent_1_estimated_punch_power            60 non-null     int64
#  3   opponent_2_estimated_punch_power            60 non-null     int64
#  4   opponent_1_estimated_punch_resistance       60 non-null     float64
#  5   opponent_2_estimated_punch_resistance       60 non-null     float64
#  6   opponent_1_estimated_ability_to_take_punch  60 non-null     float64
#  7   opponent_2_estimated_ability_to_take_punch  60 non-null     float64
#  8   opponent_1_rounds_boxed                     60 non-null     int64
#  9   opponent_2_rounds_boxed                     60 non-null     float64
#  10  opponent_1_round_ko_percentage              60 non-null     float64
#  11  opponent_2_round_ko_percentage              60 non-null     float64
#  12  opponent_1_has_been_ko_percentage           60 non-null     float64
#  13  opponent_2_has_been_ko_percentage           60 non-null     float64
#  14  opponent_1_avg_weight                       60 non-null     float64
#  15  opponent_2_avg_weight                       60 non-null     float64
#  16  Result                                      60 non-null     object
# dtypes: float64(11), int64(3), object(3)
# memory usage: 8.4+ KB

# %%
df_d.head(15)
# Out:
#                    opponent_1             opponent_2  \
# 0           Vasyl Lomachenko           Luke Campbell
# 1       Orlando Fiordigiglio           Sam Eggington
# 2           Gennady Golovkin   Sergiy Derevyanchenko
# 5               Shawn Porter         Errol Spence Jr
# 6             Zaur Abdullaev             Devin Haney
# 7                 Tyson Fury             Otto Wallin
# 9            Artur Beterbiev       Oleksandr Gvozdyk
# 12            Dereck Chisora             David Price
# 13  Olajide William Olatunji              Logan Paul
# 19         Sugar Ray Leonard           Marvin Hagler
# 20                Mike Tyson          Michael Spinks
# 21               Raul Pinzon            Saul Alvarez
# 26              Saul Alvarez           Antonio Fitch
# 30             Scott Belshaw              Tyson Fury
# 33   Carlos Leonardo Herrera            Saul Alvarez
#
#     opponent_1_estimated_punch_power  opponent_2_estimated_punch_power  \
# 0                                 72                                72
# 1                                 59                                59
# 2                                 82                                82
# 5                                 66                                66
# 6                                 64                                64
# 7                                 72                                72
# 9                                 88                                88
# 12                                65                                65
# 13                                 0                                 0
# 19                                73                                73
# 20                                83                                83
# 21                                70                                70
# 26                                67                                67
# 30                                63                                63
# 33                                57                                57
#
#     opponent_1_estimated_punch_resistance  \
# 0                                    73.9
# 1                                    55.4
# 2                                    68.0
# 5                                    63.8
# 6                                    58.4
# 7                                    66.5
# 9                                    68.4
# 12                                   63.9
# 13                                    0.0
# 19                                   66.9
# 20                                   61.8
# 21                                   39.6
# 26                                   42.4
# 30                                   49.7
# 33                                   49.0
#
#     opponent_2_estimated_punch_resistance  \
# 0                                    60.5
# 1                                    54.5
# 2                                    63.3
# 5                                    62.3
# 6                                    47.0
# 7                                    57.4
# 9                                    67.5
# 12                                   65.6
# 13                                    0.0
# 19                                   62.0
# 20                                   65.3
# 21                                   41.1
# 26                                   26.7
# 30                                   59.0
# 33                                   46.4
#
#     opponent_1_estimated_ability_to_take_punch  \
# 0                                         78.0
# 1                                         68.0
# 2                                         84.0
# 5                                         80.0
# 6                                         72.0
# 7                                         86.0
# 9                                         81.0
# 12                                        78.0
# 13                                         0.0
# 19                                        82.0
# 20                                        82.0
# 21                                        72.0
# 26                                        76.0
# 30                                        56.0
# 33                                        62.0
#
#     opponent_2_estimated_ability_to_take_punch  opponent_1_rounds_boxed  \
# 0                                         73.0                      119
# 1                                         66.0                      200
# 2                                         75.0                      200
# 5                                         77.0                      219
# 6                                         73.0                       60
# 7                                         77.0                      174
# 9                                         78.0                       52
# 12                                        70.0                      252
# 13                                         0.0                        0
# 19                                        89.0                      244
# 20                                        83.0                      119
# 21                                        71.0                       60
# 26                                        50.0                      130
# 30                                        63.0                       38
# 33                                        81.0                      116
#
#     opponent_2_rounds_boxed  opponent_1_round_ko_percentage  \
# 0                     130.0                            8.40
# 1                     177.0                            6.50
# 2                      81.0                           17.50
# 5                     108.0                            7.76
# 6                     110.0                            8.33
# 7                      90.0                           11.49
# 9                      88.0                           26.92
# 12                    105.0                            8.73
# 13                      0.0                            0.00
# 19                    386.0                            9.84
# 20                    225.0                           25.21
# 21                    129.0                           25.00
# 26                     42.0                           12.31
# 30                     11.0                           18.42
# 33                    163.0                            6.90
#
#     opponent_2_round_ko_percentage  opponent_1_has_been_ko_percentage  \
# 0                            12.31                               0.00
# 1                             8.47                               3.03
# 2                            12.35                               0.00
# 5                            19.44                               0.00
# 6                            12.73                               0.00
# 7                            14.44                               0.00
# 9                            15.91                               0.00
# 12                           18.10                               7.50
# 13                            0.00                               0.00
# 19                           13.47                               0.00
# 20                            9.33                               0.00
# 21                           11.63                               0.00
# 26                           23.81                               0.00
# 30                           45.45                               0.00
# 33                           12.88                               0.00
#
#     opponent_2_has_been_ko_percentage  opponent_1_avg_weight  \
# 0                                0.00                 127.11
# 1                                6.25                 152.50
# 2                                0.00                 159.66
# 5                                0.00                 152.53
# 6                                0.00                   0.00
# 7                                0.00                 247.50
# 9                                0.00                 178.65
# 12                              20.69                 238.35
# 13                               0.00                   0.00
# 19                               0.00                 151.51
# 20                               0.00                 369.29
# 21                               0.00                 149.60
# 26                               0.00                 155.67
# 30                               0.00                 235.48
# 33                               0.00                 148.80
#
#     opponent_2_avg_weight Result
# 0                  135.24  win_1
# 1                  148.93  win_2
# 2                  164.04  win_1
# 5                  148.47  win_2
# 6                    0.00  win_2
# 7                  240.54  win_1
# 9                  174.95  win_1
# 12                 246.75  win_1
# 13                   0.00  win_1
# 19                 177.35  win_1
# 20                 321.86  win_1
# 21                 156.18  win_2
# 26                 142.28  win_1
# 30                 249.06  win_2
# 33                 153.77  win_2

# %%
print(df_d.dtypes)
# Out:
# opponent_1                                     object
# opponent_2                                     object
# opponent_1_estimated_punch_power                int64
# opponent_2_estimated_punch_power                int64
# opponent_1_estimated_punch_resistance         float64
# opponent_2_estimated_punch_resistance         float64
# opponent_1_estimated_ability_to_take_punch    float64
# opponent_2_estimated_ability_to_take_punch    float64
# opponent_1_rounds_boxed                         int64
# opponent_2_rounds_boxed                       float64
# opponent_1_round_ko_percentage                float64
# opponent_2_round_ko_percentage                float64
# opponent_1_has_been_ko_percentage             float64
# opponent_2_has_been_ko_percentage             float64
# opponent_1_avg_weight                         float64
# opponent_2_avg_weight                         float64
# Result                                         object
# dtype: object

# %%
df_d['opponent_1_estimated_punch_power'] = df_d['opponent_1_estimated_punch_power'].astype(float).copy()
# Out:
# C:\Users\astra\AppData\Local\Temp\ipykernel_47828\1307159244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d['opponent_1_estimated_punch_power'] = df_d['opponent_1_estimated_punch_power'].astype(float).copy()

# %%
df_d['opponent_2_estimated_punch_power'] = df_d['opponent_2_estimated_punch_power'].astype(float)
# Out:
# C:\Users\astra\AppData\Local\Temp\ipykernel_47828\2457425225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d['opponent_2_estimated_punch_power'] = df_d['opponent_2_estimated_punch_power'].astype(float)

# %%
df_d['opponent_1_rounds_boxed'] = df_d['opponent_1_rounds_boxed'].astype(float)
# Out:
# C:\Users\astra\AppData\Local\Temp\ipykernel_47828\3630275238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d['opponent_1_rounds_boxed'] = df_d['opponent_1_rounds_boxed'].astype(float)

# %%
print(df_d.dtypes)
# Out:
# opponent_1                                     object
# opponent_2                                     object
# opponent_1_estimated_punch_power              float64
# opponent_2_estimated_punch_power              float64
# opponent_1_estimated_punch_resistance         float64
# opponent_2_estimated_punch_resistance         float64
# opponent_1_estimated_ability_to_take_punch    float64
# opponent_2_estimated_ability_to_take_punch    float64
# opponent_1_rounds_boxed                       float64
# opponent_2_rounds_boxed                       float64
# opponent_1_round_ko_percentage                float64
# opponent_2_round_ko_percentage                float64
# opponent_1_has_been_ko_percentage             float64
# opponent_2_has_been_ko_percentage             float64
# opponent_1_avg_weight                         float64
# opponent_2_avg_weight                         float64
# Result                                         object
# dtype: object

# %%
pearson = df_d.corr(numeric_only = True)
 
print(f"Pearson's Coefficient: {pearson}")
# Out:
# Pearson's Coefficient:                                             opponent_1_estimated_punch_power  \
# opponent_1_estimated_punch_power                                    1.000000
# opponent_2_estimated_punch_power                                    1.000000
# opponent_1_estimated_punch_resistance                               0.833214
# opponent_2_estimated_punch_resistance                               0.801379
# opponent_1_estimated_ability_to_take_punch                          0.894500
# opponent_2_estimated_ability_to_take_punch                          0.868400
# opponent_1_rounds_boxed                                             0.220500
# opponent_2_rounds_boxed                                             0.281124
# opponent_1_round_ko_percentage                                      0.659778
# opponent_2_round_ko_percentage                                      0.383015
# opponent_1_has_been_ko_percentage                                  -0.006083
# opponent_2_has_been_ko_percentage                                  -0.026049
# opponent_1_avg_weight                                               0.675980
# opponent_2_avg_weight                                               0.687828
#
#                                             opponent_2_estimated_punch_power  \
# opponent_1_estimated_punch_power                                    1.000000
# opponent_2_estimated_punch_power                                    1.000000
# opponent_1_estimated_punch_resistance                               0.833214
# opponent_2_estimated_punch_resistance                               0.801379
# opponent_1_estimated_ability_to_take_punch                          0.894500
# opponent_2_estimated_ability_to_take_punch                          0.868400
# opponent_1_rounds_boxed                                             0.220500
# opponent_2_rounds_boxed                                             0.281124
# opponent_1_round_ko_percentage                                      0.659778
# opponent_2_round_ko_percentage                                      0.383015
# opponent_1_has_been_ko_percentage                                  -0.006083
# opponent_2_has_been_ko_percentage                                  -0.026049
# opponent_1_avg_weight                                               0.675980
# opponent_2_avg_weight                                               0.687828
#
#                                             opponent_1_estimated_punch_resistance  \
# opponent_1_estimated_punch_power                                         0.833214
# opponent_2_estimated_punch_power                                         0.833214
# opponent_1_estimated_punch_resistance                                    1.000000
# opponent_2_estimated_punch_resistance                                    0.818778
# opponent_1_estimated_ability_to_take_punch                               0.911228
# opponent_2_estimated_ability_to_take_punch                               0.857692
# opponent_1_rounds_boxed                                                  0.497759
# opponent_2_rounds_boxed                                                  0.421733
# opponent_1_round_ko_percentage                                           0.238286
# opponent_2_round_ko_percentage                                           0.193667
# opponent_1_has_been_ko_percentage                                        0.085039
# opponent_2_has_been_ko_percentage                                        0.076028
# opponent_1_avg_weight                                                    0.529546
# opponent_2_avg_weight                                                    0.516985
#
#                                             opponent_2_estimated_punch_resistance  \
# opponent_1_estimated_punch_power                                         0.801379
# opponent_2_estimated_punch_power                                         0.801379
# opponent_1_estimated_punch_resistance                                    0.818778
# opponent_2_estimated_punch_resistance                                    1.000000
# opponent_1_estimated_ability_to_take_punch                               0.842759
# opponent_2_estimated_ability_to_take_punch                               0.920542
# opponent_1_rounds_boxed                                                  0.436223
# opponent_2_rounds_boxed                                                  0.444906
# opponent_1_round_ko_percentage                                           0.335025
# opponent_2_round_ko_percentage                                           0.321874
# opponent_1_has_been_ko_percentage                                        0.061323
# opponent_2_has_been_ko_percentage                                        0.073091
# opponent_1_avg_weight                                                    0.592056
# opponent_2_avg_weight                                                    0.599685
#
#                                             opponent_1_estimated_ability_to_take_punch  \
# opponent_1_estimated_punch_power                                              0.894500
# opponent_2_estimated_punch_power                                              0.894500
# opponent_1_estimated_punch_resistance                                         0.911228
# opponent_2_estimated_punch_resistance                                         0.842759
# opponent_1_estimated_ability_to_take_punch                                    1.000000
# opponent_2_estimated_ability_to_take_punch                                    0.907218
# opponent_1_rounds_boxed                                                       0.528457
# opponent_2_rounds_boxed                                                       0.424108
# opponent_1_round_ko_percentage                                                0.328816
# opponent_2_round_ko_percentage                                                0.238435
# opponent_1_has_been_ko_percentage                                             0.046567
# opponent_2_has_been_ko_percentage                                             0.040666
# opponent_1_avg_weight                                                         0.589853
# opponent_2_avg_weight                                                         0.571855
#
#                                             opponent_2_estimated_ability_to_take_punch  \
# opponent_1_estimated_punch_power                                              0.868400
# opponent_2_estimated_punch_power                                              0.868400
# opponent_1_estimated_punch_resistance                                         0.857692
# opponent_2_estimated_punch_resistance                                         0.920542
# opponent_1_estimated_ability_to_take_punch                                    0.907218
# opponent_2_estimated_ability_to_take_punch                                    1.000000
# opponent_1_rounds_boxed                                                       0.415142
# opponent_2_rounds_boxed                                                       0.546451
# opponent_1_round_ko_percentage                                                0.384859
# opponent_2_round_ko_percentage                                                0.294189
# opponent_1_has_been_ko_percentage                                             0.002186
# opponent_2_has_been_ko_percentage                                            -0.017974
# opponent_1_avg_weight                                                         0.607561
# opponent_2_avg_weight                                                         0.620209
#
#                                             opponent_1_rounds_boxed  \
# opponent_1_estimated_punch_power                           0.220500
# opponent_2_estimated_punch_power                           0.220500
# opponent_1_estimated_punch_resistance                      0.497759
# opponent_2_estimated_punch_resistance                      0.436223
# opponent_1_estimated_ability_to_take_punch                 0.528457
# opponent_2_estimated_ability_to_take_punch                 0.415142
# opponent_1_rounds_boxed                                    1.000000
# opponent_2_rounds_boxed                                    0.511740
# opponent_1_round_ko_percentage                            -0.392857
# opponent_2_round_ko_percentage                            -0.185507
# opponent_1_has_been_ko_percentage                          0.226851
# opponent_2_has_been_ko_percentage                          0.187646
# opponent_1_avg_weight                                      0.087113
# opponent_2_avg_weight                                      0.064348
#
#                                             opponent_2_rounds_boxed  \
# opponent_1_estimated_punch_power                           0.281124
# opponent_2_estimated_punch_power                           0.281124
# opponent_1_estimated_punch_resistance                      0.421733
# opponent_2_estimated_punch_resistance                      0.444906
# opponent_1_estimated_ability_to_take_punch                 0.424108
# opponent_2_estimated_ability_to_take_punch                 0.546451
# opponent_1_rounds_boxed                                    0.511740
# opponent_2_rounds_boxed                                    1.000000
# opponent_1_round_ko_percentage                            -0.109832
# opponent_2_round_ko_percentage                            -0.359450
# opponent_1_has_been_ko_percentage                          0.134939
# opponent_2_has_been_ko_percentage                          0.022431
# opponent_1_avg_weight                                      0.134254
# opponent_2_avg_weight                                      0.128768
#
#                                             opponent_1_round_ko_percentage  \
# opponent_1_estimated_punch_power                                  0.659778
# opponent_2_estimated_punch_power                                  0.659778
# opponent_1_estimated_punch_resistance                             0.238286
# opponent_2_estimated_punch_resistance                             0.335025
# opponent_1_estimated_ability_to_take_punch                        0.328816
# opponent_2_estimated_ability_to_take_punch                        0.384859
# opponent_1_rounds_boxed                                          -0.392857
# opponent_2_rounds_boxed                                          -0.109832
# opponent_1_round_ko_percentage                                    1.000000
# opponent_2_round_ko_percentage                                    0.467979
# opponent_1_has_been_ko_percentage                                -0.103072
# opponent_2_has_been_ko_percentage                                -0.100148
# opponent_1_avg_weight                                             0.605854
# opponent_2_avg_weight                                             0.642207
#
#                                             opponent_2_round_ko_percentage  \
# opponent_1_estimated_punch_power                                  0.383015
# opponent_2_estimated_punch_power                                  0.383015
# opponent_1_estimated_punch_resistance                             0.193667
# opponent_2_estimated_punch_resistance                             0.321874
# opponent_1_estimated_ability_to_take_punch                        0.238435
# opponent_2_estimated_ability_to_take_punch                        0.294189
# opponent_1_rounds_boxed                                          -0.185507
# opponent_2_rounds_boxed                                          -0.359450
# opponent_1_round_ko_percentage                                    0.467979
# opponent_2_round_ko_percentage                                    1.000000
# opponent_1_has_been_ko_percentage                                -0.086393
# opponent_2_has_been_ko_percentage                                -0.019316
# opponent_1_avg_weight                                             0.476738
# opponent_2_avg_weight                                             0.548464
#
#                                             opponent_1_has_been_ko_percentage  \
# opponent_1_estimated_punch_power                                    -0.006083
# opponent_2_estimated_punch_power                                    -0.006083
# opponent_1_estimated_punch_resistance                                0.085039
# opponent_2_estimated_punch_resistance                                0.061323
# opponent_1_estimated_ability_to_take_punch                           0.046567
# opponent_2_estimated_ability_to_take_punch                           0.002186
# opponent_1_rounds_boxed                                              0.226851
# opponent_2_rounds_boxed                                              0.134939
# opponent_1_round_ko_percentage                                      -0.103072
# opponent_2_round_ko_percentage                                      -0.086393
# opponent_1_has_been_ko_percentage                                    1.000000
# opponent_2_has_been_ko_percentage                                    0.821317
# opponent_1_avg_weight                                                0.056433
# opponent_2_avg_weight                                                0.067322
#
#                                             opponent_2_has_been_ko_percentage  \
# opponent_1_estimated_punch_power                                    -0.026049
# opponent_2_estimated_punch_power                                    -0.026049
# opponent_1_estimated_punch_resistance                                0.076028
# opponent_2_estimated_punch_resistance                                0.073091
# opponent_1_estimated_ability_to_take_punch                           0.040666
# opponent_2_estimated_ability_to_take_punch                          -0.017974
# opponent_1_rounds_boxed                                              0.187646
# opponent_2_rounds_boxed                                              0.022431
# opponent_1_round_ko_percentage                                      -0.100148
# opponent_2_round_ko_percentage                                      -0.019316
# opponent_1_has_been_ko_percentage                                    0.821317
# opponent_2_has_been_ko_percentage                                    1.000000
# opponent_1_avg_weight                                                0.124700
# opponent_2_avg_weight                                                0.134745
#
#                                             opponent_1_avg_weight  \
# opponent_1_estimated_punch_power                         0.675980
# opponent_2_estimated_punch_power                         0.675980
# opponent_1_estimated_punch_resistance                    0.529546
# opponent_2_estimated_punch_resistance                    0.592056
# opponent_1_estimated_ability_to_take_punch               0.589853
# opponent_2_estimated_ability_to_take_punch               0.607561
# opponent_1_rounds_boxed                                  0.087113
# opponent_2_rounds_boxed                                  0.134254
# opponent_1_round_ko_percentage                           0.605854
# opponent_2_round_ko_percentage                           0.476738
# opponent_1_has_been_ko_percentage                        0.056433
# opponent_2_has_been_ko_percentage                        0.124700
# opponent_1_avg_weight                                    1.000000
# opponent_2_avg_weight                                    0.977274
#
#                                             opponent_2_avg_weight
# opponent_1_estimated_punch_power                         0.687828
# opponent_2_estimated_punch_power                         0.687828
# opponent_1_estimated_punch_resistance                    0.516985
# opponent_2_estimated_punch_resistance                    0.599685
# opponent_1_estimated_ability_to_take_punch               0.571855
# opponent_2_estimated_ability_to_take_punch               0.620209
# opponent_1_rounds_boxed                                  0.064348
# opponent_2_rounds_boxed                                  0.128768
# opponent_1_round_ko_percentage                           0.642207
# opponent_2_round_ko_percentage                           0.548464
# opponent_1_has_been_ko_percentage                        0.067322
# opponent_2_has_been_ko_percentage                        0.134745
# opponent_1_avg_weight                                    0.977274
# opponent_2_avg_weight                                    1.000000

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.heatmap(df.corr(numeric_only=True),ax=ax, annot=True)
# Out:
# <Axes: >

# %%
###### Engineering New Features ########

### Make a new feature for punch resistance
df_d['resistance_diff'] = df_d.opponent_1_estimated_punch_resistance - df_d.opponent_2_estimated_punch_resistance 

### Make a new feature for ability to take punch 
df_d['take_diff'] = df_d.opponent_1_estimated_ability_to_take_punch - df_d.opponent_2_estimated_ability_to_take_punch 


### Make a new feature for rounds boxed
df_d['boxround_diff'] = df_d.opponent_1_rounds_boxed - df_d.opponent_2_rounds_boxed    

### Make a new feature for KO percentage of wins
df_d['koround_diff'] = df_d.opponent_1_round_ko_percentage - df_d.opponent_2_round_ko_percentage     


### Make a new feature for Win Percentage
df_d['weight_diff'] = df_d.opponent_1_avg_weight - df_d.opponent_2_avg_weight   



df_d.head()
# Out:
# C:\Users\astra\AppData\Local\Temp\ipykernel_47828\2903860487.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d['resistance_diff'] = df_d.opponent_1_estimated_punch_resistance - df_d.opponent_2_estimated_punch_resistance
# C:\Users\astra\AppData\Local\Temp\ipykernel_47828\2903860487.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d['take_diff'] = df_d.opponent_1_estimated_ability_to_take_punch - df_d.opponent_2_estimated_ability_to_take_punch
# C:\Users\astra\AppData\Local\Temp\ipykernel_47828\2903860487.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d['boxround_diff'] = df_d.opponent_1_rounds_boxed - df_d.opponent_2_rounds_boxed
# C:\Users\astra\AppData\Local\Temp\ipykernel_47828\2903860487.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d['koround_diff'] = df_d.opponent_1_round_ko_percentage - df_d.opponent_2_round_ko_percentage
# C:\Users\astra\AppData\Local\Temp\ipykernel_47828\2903860487.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_d['weight_diff'] = df_d.opponent_1_avg_weight - df_d.opponent_2_avg_weight
#               opponent_1             opponent_2  \
# 0      Vasyl Lomachenko           Luke Campbell
# 1  Orlando Fiordigiglio           Sam Eggington
# 2      Gennady Golovkin   Sergiy Derevyanchenko
# 5          Shawn Porter         Errol Spence Jr
# 6        Zaur Abdullaev             Devin Haney
#
#    opponent_1_estimated_punch_power  opponent_2_estimated_punch_power  \
# 0                              72.0                              72.0
# 1                              59.0                              59.0
# 2                              82.0                              82.0
# 5                              66.0                              66.0
# 6                              64.0                              64.0
#
#    opponent_1_estimated_punch_resistance  \
# 0                                   73.9
# 1                                   55.4
# 2                                   68.0
# 5                                   63.8
# 6                                   58.4
#
#    opponent_2_estimated_punch_resistance  \
# 0                                   60.5
# 1                                   54.5
# 2                                   63.3
# 5                                   62.3
# 6                                   47.0
#
#    opponent_1_estimated_ability_to_take_punch  \
# 0                                        78.0
# 1                                        68.0
# 2                                        84.0
# 5                                        80.0
# 6                                        72.0
#
#    opponent_2_estimated_ability_to_take_punch  opponent_1_rounds_boxed  \
# 0                                        73.0                    119.0
# 1                                        66.0                    200.0
# 2                                        75.0                    200.0
# 5                                        77.0                    219.0
# 6                                        73.0                     60.0
#
#    opponent_2_rounds_boxed  ...  opponent_1_has_been_ko_percentage  \
# 0                    130.0  ...                               0.00
# 1                    177.0  ...                               3.03
# 2                     81.0  ...                               0.00
# 5                    108.0  ...                               0.00
# 6                    110.0  ...                               0.00
#
#    opponent_2_has_been_ko_percentage  opponent_1_avg_weight  \
# 0                               0.00                 127.11
# 1                               6.25                 152.50
# 2                               0.00                 159.66
# 5                               0.00                 152.53
# 6                               0.00                   0.00
#
#    opponent_2_avg_weight  Result  resistance_diff take_diff  boxround_diff  \
# 0                 135.24   win_1             13.4       5.0          -11.0
# 1                 148.93   win_2              0.9       2.0           23.0
# 2                 164.04   win_1              4.7       9.0          119.0
# 5                 148.47   win_2              1.5       3.0          111.0
# 6                   0.00   win_2             11.4      -1.0          -50.0
#
#    koround_diff  weight_diff
# 0         -3.91        -8.13
# 1         -1.97         3.57
# 2          5.15        -4.38
# 5        -11.68         4.06
# 6         -4.40         0.00
#
# [5 rows x 22 columns]

# %%
"Result" in df_d.columns
# Out:
# True

# %%
print(df_d.columns.tolist())
# Out:
# ['opponent_1', 'opponent_2', 'opponent_1_estimated_punch_power', 'opponent_2_estimated_punch_power', 'opponent_1_estimated_punch_resistance', 'opponent_2_estimated_punch_resistance', 'opponent_1_estimated_ability_to_take_punch', 'opponent_2_estimated_ability_to_take_punch', 'opponent_1_rounds_boxed', 'opponent_2_rounds_boxed', 'opponent_1_round_ko_percentage', 'opponent_2_round_ko_percentage', 'opponent_1_has_been_ko_percentage', 'opponent_2_has_been_ko_percentage', 'opponent_1_avg_weight', 'opponent_2_avg_weight', 'Result', 'resistance_diff', 'take_diff', 'boxround_diff', 'koround_diff', 'weight_diff']

# %%
df_d.index.names
# Out:
# FrozenList([None])

# %%
X = df_d[['opponent_1_estimated_punch_power', 'opponent_2_estimated_punch_power', 
          'opponent_1_rounds_boxed', 'opponent_2_rounds_boxed', 
          'opponent_1_avg_weight', 'opponent_2_avg_weight']]  # Example features

# %%
y = df_d['Result']

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
le = LabelEncoder()

# Fit and transform the 'Result' column to numeric values
y_encoded = le.fit_transform(y)

# %%
# Step 5: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
# Step 6: Scale the features
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
# Step 9: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[251], line 2
#       1 # Step 9: Evaluate the model
# ----> 2 accuracy = accuracy_score(y_test, y_pred)
#       3 print(f'Accuracy: {accuracy:.2f}')
#
# NameError: name 'y_pred' is not defined

# %%
# Optionally, you can also print the classification report for more insights
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=le.classes_))

# %%
from pandas.plotting import scatter_matrix

# Dropping the 'result' column to enter into y_train
 

y = pd.read_csv('d.csv')
y['Result'] = y['Result'].str.strip()
print(y)
# Out:
#    Result
# 0    win1
# 1    win2
# 2    win1
# 3    win2
# 4    win2
# 5    win1
# 6    win1
# 7    win1
# 8    win1
# 9    win1
# 10   win1
# 11   win2
# 12   win1
# 13   win2
# 14   win2
# 15   win2
# 16   win1
# 17   win2
# 18   draw
# 19   win2
# 20   win1
# 21   win2
# 22   win2
# 23   win1
# 24   win1
# 25   win2
# 26   win2
# 27   win1
# 28   win1
# 29   draw
# 30   draw
# 31   win2
# 32   win2
# 33   win2
# 34   win2
# 35   win2
# 36   win2
# 37   win2
# 38   win2
# 39   win2
# 40   win1
# 41   win2
# 42   win2
# 43   win1
# 44   win2
# 45   win2
# 46   draw
# 47   win1
# 48   win2
# 49   win2
# 50   win2
# 51   win2
# 52   win1
# 53   win1
# 54   draw
# 55   win1
# 56   win2
# 57   win2
# 58   win2
# 59   win2

# %%
X = df_d.drop(['opponent_1', 'opponent_2','Result'], axis='columns')

# %%
X.head()
# Out:
#    opponent_1_estimated_punch_power  opponent_2_estimated_punch_power  \
# 0                              72.0                              72.0
# 1                              59.0                              59.0
# 2                              82.0                              82.0
# 5                              66.0                              66.0
# 6                              64.0                              64.0
#
#    opponent_1_estimated_punch_resistance  \
# 0                                   73.9
# 1                                   55.4
# 2                                   68.0
# 5                                   63.8
# 6                                   58.4
#
#    opponent_2_estimated_punch_resistance  \
# 0                                   60.5
# 1                                   54.5
# 2                                   63.3
# 5                                   62.3
# 6                                   47.0
#
#    opponent_1_estimated_ability_to_take_punch  \
# 0                                        78.0
# 1                                        68.0
# 2                                        84.0
# 5                                        80.0
# 6                                        72.0
#
#    opponent_2_estimated_ability_to_take_punch  opponent_1_rounds_boxed  \
# 0                                        73.0                    119.0
# 1                                        66.0                    200.0
# 2                                        75.0                    200.0
# 5                                        77.0                    219.0
# 6                                        73.0                     60.0
#
#    opponent_2_rounds_boxed  opponent_1_round_ko_percentage  \
# 0                    130.0                            8.40
# 1                    177.0                            6.50
# 2                     81.0                           17.50
# 5                    108.0                            7.76
# 6                    110.0                            8.33
#
#    opponent_2_round_ko_percentage  opponent_1_has_been_ko_percentage  \
# 0                           12.31                               0.00
# 1                            8.47                               3.03
# 2                           12.35                               0.00
# 5                           19.44                               0.00
# 6                           12.73                               0.00
#
#    opponent_2_has_been_ko_percentage  opponent_1_avg_weight  \
# 0                               0.00                 127.11
# 1                               6.25                 152.50
# 2                               0.00                 159.66
# 5                               0.00                 152.53
# 6                               0.00                   0.00
#
#    opponent_2_avg_weight  resistance_diff  take_diff  boxround_diff  \
# 0                 135.24             13.4        5.0          -11.0
# 1                 148.93              0.9        2.0           23.0
# 2                 164.04              4.7        9.0          119.0
# 5                 148.47              1.5        3.0          111.0
# 6                   0.00             11.4       -1.0          -50.0
#
#    koround_diff  weight_diff
# 0         -3.91        -8.13
# 1         -1.97         3.57
# 2          5.15        -4.38
# 5        -11.68         4.06
# 6         -4.40         0.00

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# summarize
print('Train', X_train.shape, y_train.shape)
print('Test', X_test.shape, y_test.shape)
# Out:
# Train (45, 19) (45, 1)
# Test (15, 19) (15, 1)

# %%
# one-hot encode target variables
onehot_encoder = OneHotEncoder()
onehot_encoder.fit(y_train)
y_train = onehot_encoder.transform(y_train)
y_test = onehot_encoder.transform(y_test)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train=scaler.transform(X_train)
X_test= scaler.transform(X_test)

# %%
X_trainT     = X_train.reshape(23,19)
y_trainT     = y_train.reshape(23,19)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3023], line 1
# ----> 1 X_trainT     = X_train.reshape(23,19)
#       2 y_trainT     = y_train.reshape(23,19)
#
# ValueError: cannot reshape array of size 855 into shape (23,19)

# %%
print('Train', X_trainT.shape, y_trainT.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3025], line 1
# ----> 1 print('Train', X_trainT.shape, y_trainT.shape)
#
# NameError: name 'X_trainT' is not defined

# %%
print('Train', y_test.shape, y_train.shape)
# Out:
# Train (15, 3) (45, 3)

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from mlxtend.preprocessing import DenseTransformer
import re
import numpy as np



pipe_1 = Pipeline([
    ('vect', CountVectorizer()),
    ('to_dense', DenseTransformer()),
    ('clf', RandomForestClassifier())
])

parameters_1 = dict(
    clf__n_estimators=[50, 100, 200],
    clf__max_features=['sqrt', 'log2', None],)

grid_search_1 = GridSearchCV(pipe_1, 
                             parameters_1, 
                             n_jobs=1, 
                             verbose=1,
                             scoring='accuracy',
                             cv=2)


print("Performing grid search...")
print("pipeline:", [name for name, _ in pipe_1.steps])
print("parameters:")
grid_search_1.fit(X_train, y_train)
print("Best score: %0.3f" % grid_search_1.best_score_)
print("Best parameters set:")
best_parameters_1 = grid_search_1.best_estimator_.get_params()
for param_name in sorted(parameters_1.keys()):
    print("\t%s: %r" % (param_name, best_parameters_1[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'to_dense', 'clf']
# parameters:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2875], line 32
#      30 print("pipeline:", [name for name, _ in pipe_1.steps])
#      31 print("parameters:")
# ---> 32 grid_search_1.fit(X_train, y_train)
#      33 print("Best score: %0.3f" % grid_search_1.best_score_)
#      34 print("Best parameters set:")
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:851, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     844 elif len(out) != n_candidates * n_splits:
#     845     raise ValueError(
#     846         "cv.split and cv.get_n_splits returned "
#     847         "inconsistent results. Expected {} "
#     848         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     849     )
# --> 851 _warn_or_raise_about_fit_failures(out, self.error_score)
#     853 # For callable self.scoring, the return type is only know after
#     854 # calling. If the return type is a dictionary, the error scores
#     855 # can now be inserted with the correct key. The type checking
#     856 # of out will be done in `_insert_error_scores`.
#     857 if callable(self.scoring):
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 18 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 345, in fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\base.py", line 584, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1124, in check_X_y
#     check_consistent_length(X, y)
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 397, in check_consistent_length
#     raise ValueError(
# ValueError: Found input variables with inconsistent numbers of samples: [19, 22]
#
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 345, in fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\base.py", line 584, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1124, in check_X_y
#     check_consistent_length(X, y)
#   File "C:\Users\astra\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 397, in check_consistent_length
#     raise ValueError(
# ValueError: Found input variables with inconsistent numbers of samples: [19, 23]
